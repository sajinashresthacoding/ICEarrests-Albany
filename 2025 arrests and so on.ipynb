# %%
## import necessary libraries
import pandas as pd

# %%
df1 = pd.read_csv('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/RawData/2025_pt1.csv')

# %%
df1
# Out:
#           Apprehension Date Apprehension Type           State  County  \
# 0       2025-09-17 11:34:21          Targeted           TEXAS     NaN
# 1       2025-07-15 12:35:19               NaN         INDIANA     NaN
# 2       2025-09-19 15:18:01          Targeted    PENNSYLVANIA     NaN
# 3       2025-01-26 14:49:00               NaN  NORTH CAROLINA     NaN
# 4       2025-02-19 00:00:00               NaN          KANSAS     NaN
# ...                     ...               ...             ...     ...
# 203816  2025-09-30 16:58:11        Collateral           TEXAS     NaN
# 203817  2025-09-30 19:52:05          Targeted           TEXAS     NaN
# 203818  2025-09-30 20:09:40          Targeted      CALIFORNIA     NaN
# 203819  2025-09-30 20:32:00          Targeted      CALIFORNIA     NaN
# 203820  2025-08-19 12:38:00          Targeted        NEW YORK     NaN
#
#                         TOA Current Duty AOR   Apprehension Final Program  \
# ...

# %%
df2 = pd.read_csv('/Users/sajinashrestha/Documents/dataProjects/WAMC/ICE Arrests/RawData/2025_pt2.csv')

# %%
df2
# Out:
#           Apprehension Date Apprehension Type     State  County  \
# 0       2025-11-16 14:21:59          Targeted     TEXAS     NaN
# 1       2025-11-05 14:29:30        Collateral     TEXAS     NaN
# 2       2025-12-14 08:18:33          Targeted      UTAH     NaN
# 3       2026-02-14 10:27:08          Targeted   FLORIDA     NaN
# 4       2025-11-19 07:44:46          Targeted  ILLINOIS     NaN
# ...                     ...               ...       ...     ...
# 191541  2026-03-10 17:07:39        Collateral     TEXAS     NaN
# 191542  2026-03-10 17:22:39        Collateral     TEXAS     NaN
# 191543  2026-03-10 17:21:11        Collateral     TEXAS     NaN
# 191544  2026-03-10 16:14:39        Collateral     TEXAS     NaN
# 191545  2026-03-10 18:26:43               NaN       NaN     NaN
#
#                          TOA Current Duty AOR   Apprehension Final Program  \
# 0          San Antonio Area of Responsibility   ERO Criminal Alien Program
# ...

# %%
secondterm = pd.concat([df1, df2])

# %%
secondterm
# Out:
#           Apprehension Date Apprehension Type           State  County  \
# 0       2025-09-17 11:34:21          Targeted           TEXAS     NaN
# 1       2025-07-15 12:35:19               NaN         INDIANA     NaN
# 2       2025-09-19 15:18:01          Targeted    PENNSYLVANIA     NaN
# 3       2025-01-26 14:49:00               NaN  NORTH CAROLINA     NaN
# 4       2025-02-19 00:00:00               NaN          KANSAS     NaN
# ...                     ...               ...             ...     ...
# 191541  2026-03-10 17:07:39        Collateral           TEXAS     NaN
# 191542  2026-03-10 17:22:39        Collateral           TEXAS     NaN
# 191543  2026-03-10 17:21:11        Collateral           TEXAS     NaN
# 191544  2026-03-10 16:14:39        Collateral           TEXAS     NaN
# 191545  2026-03-10 18:26:43               NaN             NaN     NaN
#
#                        TOA Current Duty AOR   Apprehension Final Program  \
# ...

# %%
secondterm["State"].value_counts()
# Out:
# TEXAS                    94525
# FLORIDA                  37027
# CALIFORNIA               33557
# NEW YORK                 13895
# GEORGIA                  13743
#                          ...
# ARMED FORCES - EUROPE        2
# OTHER                        2
# MEXICO                       1
# TAMAULIPAS                   1
# CHIAPAS                      1
# Name: State, Length: 63, dtype: int64

# %%
statecount = secondterm["State"].value_counts()

# %%
statecount.to_csv('RawData/DeportationByState.csv', index=True)

# %%
df_NY = secondterm.query('State == "NEW YORK"')

# %%
df_NY
# Out:
#           Apprehension Date Apprehension Type     State  County  \
# 14      2025-09-16 08:33:41        Collateral  NEW YORK     NaN
# 39      2025-01-28 12:26:00               NaN  NEW YORK     NaN
# 48      2025-07-25 11:29:25               NaN  NEW YORK     NaN
# 66      2025-06-09 13:03:41               NaN  NEW YORK     NaN
# 89      2025-09-12 14:29:15          Targeted  NEW YORK     NaN
# ...                     ...               ...       ...     ...
# 184814  2025-10-21 08:34:15        Collateral  NEW YORK     NaN
# 185156  2025-10-31 07:20:00        Collateral  NEW YORK     NaN
# 186543  2025-12-03 10:26:19          Targeted  NEW YORK     NaN
# 186642  2025-12-04 17:20:00        Collateral  NEW YORK     NaN
# 189191  2025-12-28 20:40:32        Collateral  NEW YORK     NaN
#
#                         TOA Current Duty AOR   Apprehension Final Program  \
# 14             Boston Area of Responsibility          Fugitive Operations
# ...

# %%
NYcounts = df_NY['Apprehension Site Landmark'].value_counts()

# %%
NYcounts.to_csv('RawData/DeportationByNY.csv', index=True)

# %%
df_NY['Apprehension Site Landmark'].unique()
# Out:
# array(['FUGITIVE OPERATIONS MA', 'NDD - 26 FEDERAL PLAZA NY, NY',
#        'CIP GENERAL AREA, NON-SPECIFIC', 'ATD NY STATE', 'ALBANY COUNTY',
#        'RENSSELAER COUNTY', 'ERIE COUNTY',
#        'WHP GENERAL AREA, NON-SPECIFIC', 'ONONDAGA COUNTY',
#        'SCHENECTADY COUNTY', 'FUGITIVE OPERATIONS NY STATE',
#        'NBG GENERAL AREA, NON-SPECIFIC', 'NON-DETAINED and Juvenile',
#        'CLINTON COUNTY', 'CAP - BOP BROOKLYN NY STATE',
#        'FOS GENERAL AREA, NON-SPECIFIC', 'MONROE COUNTY',
#        'SARATOGA COUNTY', 'JCART STREET ARREST NY STATE',
#        'OSWEGO COUNTY JAIL', 'CHAUTAUQUA COUNTY',
#        'MIDSTATE CORRECTIONAL FACILITY',
#        'CAP - QUEENSBORO CORRECTIONAL FACILITY NY STATE',
#        'CATTARAUGUS COUNTY', 'CAP - USM - SOUTHERN DISTRICT NY STATE',
#        'CAP - NASSAU COUNTY JAIL NY STATE',
#        'NEW GENERAL AREA, NON-SPECIFIC', 'WENDE CORRECTIONAL FACILITY',
#        'GREENE COUNTY', 'TIOGA COUNTY', 'FISHKILL CORRECTIONAL FACILITY',
# ...

# %%
CapitalRegion= ['ALBANY COUNTY','RENSSELAER COUNTY', 'SARATOGA COUNTY', 'GREENE COUNTY', 'WARREN COUNTY', 'WARREN COUNTY JAIL', 'SCHENECTADY COUNTY JAIL', 'SARATOGA COUNTY JAIL', 'RENSSELAER COUNTY JAIL', 'WASHINGTON CORRECTIONAL FACILITY', 'WASHINGTON COUNTY JAIL']

# %%
df_CR = df_NY[df_NY['Apprehension Site Landmark'].isin(CapitalRegion)]

# %%
df_CR
# Out:
#           Apprehension Date Apprehension Type     State  County  \
# 193     2025-07-14 10:50:35               NaN  NEW YORK     NaN
# 259     2025-06-13 17:34:11               NaN  NEW YORK     NaN
# 694     2025-07-28 09:57:24               NaN  NEW YORK     NaN
# 1851    2025-07-28 14:27:27               NaN  NEW YORK     NaN
# 1920    2025-06-29 08:35:08               NaN  NEW YORK     NaN
# ...                     ...               ...       ...     ...
# 180946  2026-01-12 10:52:18          Targeted  NEW YORK     NaN
# 181196  2025-12-18 12:27:18        Collateral  NEW YORK     NaN
# 181397  2025-12-02 08:18:41          Targeted  NEW YORK     NaN
# 181401  2025-11-19 11:59:32          Targeted  NEW YORK     NaN
# 183874  2025-10-17 09:20:31        Collateral  NEW YORK     NaN
#
#                   TOA Current Duty AOR  Apprehension Final Program  \
# 193     Buffalo Area of Responsibility         Fugitive Operations
# ...

# %%
df_CR["Apprehension Site Landmark"].value_counts()
# Out:
# SARATOGA COUNTY                     340
# ALBANY COUNTY                       285
# RENSSELAER COUNTY                    82
# WARREN COUNTY                        29
# GREENE COUNTY                        13
# SCHENECTADY COUNTY JAIL               8
# SARATOGA COUNTY JAIL                  5
# RENSSELAER COUNTY JAIL                3
# WARREN COUNTY JAIL                    2
# WASHINGTON CORRECTIONAL FACILITY      1
# WASHINGTON COUNTY JAIL                1
# Name: Apprehension Site Landmark, dtype: int64
